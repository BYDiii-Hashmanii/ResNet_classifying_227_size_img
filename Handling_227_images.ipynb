# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,BatchNormalization,Activation
from keras.models import Sequential
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
data =pd.read_csv('Bewerage_110.csv',low_memory=False)

# %%
x = data.drop(columns=['0']).astype('float')/255
y= data['0']

# %%
x= x.to_numpy()
x= x.reshape(2526,110,110,3)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_train = to_categorical(y_train, num_classes=6)
y_test  = to_categorical(y_test,  num_classes=6)

# %%
# Le NEt Architecture >>> For My model
le_net_model = Sequential(
    [
     Conv2D(32,kernel_size=(3,3),padding='valid',input_shape=x.shape[1:]),
     BatchNormalization(),
     Activation('relu'),
     MaxPooling2D(2,2),

     Conv2D(64,kernel_size=(3,3),padding='valid'),
     BatchNormalization(),
     Activation('relu'),
     MaxPooling2D(2,2),

     Conv2D(128,kernel_size=(3,3),padding='valid'),
     BatchNormalization(),
     Activation('relu'),
     MaxPooling2D(2,2),

     Conv2D(256,kernel_size=(3,3),padding='valid'),
     BatchNormalization(),
     Activation('relu'),
     MaxPooling2D(2,2),

    Flatten()  ,
    Dense(128,activation='relu'),
    Dense(6,activation='softmax')
    ]
)
le_net_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 108, 108, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 108, 108, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
le_net_model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics = ['accuracy'])

# %%
le_net_model.fit(x_train,y_train,validation_data=(x_test,y_test),verbose=1,epochs=20)

# %%
print("hello ")
# Out:
# hello

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
output_csv_path = '/content/drive/MyDrive/Bewerage_227.csv'

# %%
import os
import cv2
import csv

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

label_dic = {'cardboard':0,'glass':1,'metal':2,'paper':3,'plastic':4,'trash':5}
classes = list(label_dic.keys())

# Save CSV inside Google Drive
output_csv_path = '/content/drive/MyDrive/Bewerage_227.csv'

with open(output_csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    for cls in classes:
        # Correct path
        path = f'/content/drive/MyDrive/Garbage classification/{cls}'  # Must match folder names

        for r, d, files in os.walk(path):
            for filename in files:
                if filename.endswith('.jpg'):
                    record = []
                    file_path = os.path.join(r, filename)
                    image = cv2.imread(file_path)
                    image = cv2.resize(image, (227, 227))

                    label = label_dic[cls]   # Correct label
                    record.append(label)
                    record.extend(image.flatten())  # Convert the image to 1D

                    writer.writerow(record)

print(f"CSV saved to: {output_csv_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV saved to: /content/drive/MyDrive/Bewerage_227.csv

# %%
data_227 = pd.read_csv('/content/drive/MyDrive/Bewerage_227.csv')

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

def identity_block(X, f, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
    X_shortcut = X

    # First component
    X = layers.Conv2D(F1, (1,1), strides=(1,1), padding='valid', name=conv_name_base+'2a')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2a')(X)
    X = layers.Activation('relu')(X)

    # Second component
    X = layers.Conv2D(F2, (f,f), strides=(1,1), padding='same', name=conv_name_base+'2b')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2b')(X)
    X = layers.Activation('relu')(X)

    # Third component
    X = layers.Conv2D(F3, (1,1), strides=(1,1), padding='valid', name=conv_name_base+'2c')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2c')(X)

    # Add shortcut
    X = layers.Add()([X, X_shortcut])
    X = layers.Activation('relu')(X)
    return X

def convolutional_block(X, f, filters, stage, block, s=2):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
    X_shortcut = X

    # First component
    X = layers.Conv2D(F1, (1,1), strides=(s,s), padding='valid', name=conv_name_base+'2a')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2a')(X)
    X = layers.Activation('relu')(X)

    # Second component
    X = layers.Conv2D(F2, (f,f), strides=(1,1), padding='same', name=conv_name_base+'2b')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2b')(X)
    X = layers.Activation('relu')(X)

    # Third component
    X = layers.Conv2D(F3, (1,1), strides=(1,1), padding='valid', name=conv_name_base+'2c')(X)
    X = layers.BatchNormalization(name=bn_name_base+'2c')(X)

    # Shortcut path
    X_shortcut = layers.Conv2D(F3, (1,1), strides=(s,s), padding='valid', name=conv_name_base+'1')(X_shortcut)
    X_shortcut = layers.BatchNormalization(name=bn_name_base+'1')(X_shortcut)

    # Add shortcut
    X = layers.Add()([X, X_shortcut])
    X = layers.Activation('relu')(X)
    return X

def ResNet50_227(input_shape=(227,227,3), classes=6):
    X_input = layers.Input(input_shape)

    # Stage 1
    X = layers.ZeroPadding2D((3,3))(X_input)
    X = layers.Conv2D(64, (7,7), strides=(2,2), name='conv1')(X)
    X = layers.BatchNormalization(name='bn_conv1')(X)
    X = layers.Activation('relu')(X)
    X = layers.MaxPooling2D((3,3), strides=(2,2))(X)

    # Stage 2
    X = convolutional_block(X, f=3, filters=[64,64,256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64,64,256], stage=2, block='b')
    X = identity_block(X, 3, [64,64,256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f=3, filters=[128,128,512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128,128,512], stage=3, block='b')
    X = identity_block(X, 3, [128,128,512], stage=3, block='c')
    X = identity_block(X, 3, [128,128,512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f=3, filters=[256,256,1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256,256,1024], stage=4, block='b')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='c')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='d')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='e')
    X = identity_block(X, 3, [256,256,1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f=3, filters=[512,512,2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512,512,2048], stage=5, block='b')
    X = identity_block(X, 3, [512,512,2048], stage=5, block='c')

    # Average Pooling
    X = layers.GlobalAveragePooling2D()(X)

    # Output layer
    X = layers.Dense(classes, activation='softmax', name='fc'+str(classes))(X)

    model = Model(inputs=X_input, outputs=X, name='ResNet50_227')
    return model

# Create the model
model = ResNet50_227(input_shape=(227,227,3), classes=6)
model.summary()
